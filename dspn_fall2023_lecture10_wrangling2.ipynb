# %% [markdown]
# # Data Science in Psychology & Neuroscience (DSPN):
#
# ## Lecture 9. Data Wrangling (part 2)
#
# ### Date: September 26, 2023
#
# ### To-Dos From Last Class:
#
# * Download data for today's wrangling session #1 dataset from <a href="https://github.com/hogeveen-lab/DSPN_Fall2022_Git/tree/master/misc_exercises/imitation_inhibition_paradigm">Github</a>
#
# ### Today:
#
# * Data wrangling in Pandas (stealing heavily from this <a href="https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf">Cheatsheet</a>)
#     * Last part of last class: Combining data frames
# * Wrangle some real data
#
# ### Homework
#
# * Download <a href="https://github.com/hogeveen-lab/DSPN_Fall2022_Git/tree/master/assignment_starters/assign3_starter">Assignment #3 starter kit</a>

# %% [markdown]
# # Data wrangling in Pandas
#
# ## (finishing from last class) 5. Combining Data Sets
#
# <img src="img/combining_data.png" width="600">

# %%
import pandas as pd
import numpy as np

# function to generate random integers
def random_integer(x,n):
    for i in range(n):
        x.append(np.random.randint(25,75))
    return x

# running the function and check the output
x = []
random_integer(x,6)
# print(x)

# putting together some example data frames
df1 = pd.DataFrame({'pid' : ['P1','P2','P3'],
                   'var1' : [x[0],x[1],x[2]]})
# display(df1)
df2 = pd.DataFrame({'pid' : ['P1','P2','P4'],
                   'var2' : [x[3],x[4],x[5]]})
# display(df2)

# Standard merge approach #1
print('Merge LEFT (right --> left; lose unique rows from the RIGHT df)')
merge_left = pd.merge(df1,df2,on='pid',how='left')
display(merge_left)

# Standard merge approach #2
print('Merge RIGHT (left --> right; lose unique rows from the LEFT df)')
merge_right = pd.merge(df1,df2,on='pid',how='right')
display(merge_right)

# Standard merge approach #3
print('Merge INNER (lose unique data from BOTH dfs)')
merge_inner = pd.merge(df1,df2,on='pid',how='inner')
display(merge_inner)

# Standard merge approach #4
print('Merge OUTER (retain ALL the data)')
merge_outer = pd.merge(df1,df2,on='pid',how='outer')
display(merge_outer)
# Out:
# Merge LEFT (right --> left; lose unique rows from the RIGHT df)
#   pid  var1  var2
# 0  P1    59  72.0
# 1  P2    40  72.0
# 2  P3    30   NaN
# Merge RIGHT (left --> right; lose unique rows from the LEFT df)
#   pid  var1  var2
# 0  P1  59.0    72
# 1  P2  40.0    72
# 2  P4   NaN    42
# Merge INNER (lose unique data from BOTH dfs)
#   pid  var1  var2
# 0  P1    59    72
# 1  P2    40    72
# Merge OUTER (retain ALL the data)
#   pid  var1  var2
# 0  P1  59.0  72.0
# 1  P2  40.0  72.0
# 2  P3  30.0   NaN
# 3  P4   NaN  42.0

# %% [markdown]
# # Wrangle some real data
#
# <img src="img/imit_inhib_fileorg.png" width=500>

# %% [markdown]
# ## Breaking into 8 code chunks
# ## 1. Import packages

# %%
### Part 1 --> Importing data wrangling packages I often use
import os
from glob import glob # only need the glob subpackage from glob
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## 2. Setting paths to the first level data

# %%
### Part 2 --> setting paths to the first level data

# get current working directory
base_dir = os.getcwd()

# Go above current working directory and
first_dir = os.path.join(base_dir,'misc/imitation_inhibition_paradigm/data/first')
P_file_pattern = 'P*.txt'
second_dir = os.path.join(base_dir,'misc/imitation_inhibition_paradigm/data/second')
questionnaire_file = os.path.join(second_dir,'ait_questionnaires.csv')

# Using glob to find all participant data files
all_files = glob(os.path.join(first_dir,P_file_pattern))
print(all_files)
# Out:
# ['/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P8.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P9.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P49.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P48.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P13.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P12.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P38.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P10.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P11.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P39.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P15.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P29.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P28.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P14.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P16.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P17.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P32.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P26.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P27.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P33.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P19.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P25.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P31.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P30.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P24.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P18.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P20.txt', '/Use ...

# %%
# Using glob to find all participant data files
all_files = glob('/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P*.txt')
print(all_files)
# Out:
# ['/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P8.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P9.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P49.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P48.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P13.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P12.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P38.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P10.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P11.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P39.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P15.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P29.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P28.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P14.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P16.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P17.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P32.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P26.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P27.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P33.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P19.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P25.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P31.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P30.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P24.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P18.txt', '/Users/jeremyhogeveen/Dropbox/Fall_2023/teaching/PSY450_650/DSPN_Fall2023_workdir/lectures/misc/imitation_inhibition_paradigm/data/first/P20.txt', '/Use ...

# %% [markdown]
# ## 3. Load a test subject to make sense of things

# %%
### Part 3 --> Loading in a test subject to make sense of things

# Reading in the data
sample_df = pd.read_csv(all_files[0], error_bad_lines=False, skiprows=5, sep='\t')
print('How many rows in initial loaded data frame:',len(sample_df)) # What things might cause this to not == 100?
# Filtering the data down to just the experimental block rows
sample_df = sample_df[sample_df['Name.1']=="AI_Block"]
sample_df.loc[:, 'Finger':'Repeated']
sample_df.loc[50:300, :]

# Filtering the df down to just the key release responses
sample_df_releases = sample_df[sample_df['Released']=='Released'] 

# How many key release responses do we have?
print('How many rows in key release filtered data frame:',len(sample_df_releases)) # What things might cause this to not == 100? For now, just worry baout double responses. For this task, error rates so low that miss response trials not really important.

# Identifying double responses
sample_df_releases['shift'] = sample_df_releases['Name.2'].shift() # creating a new column ('shift') based on the next row of our trial name column. "SettingWithCopyWarning".
# display(sample_df_releases[['Name.2','shift']]) # checking that it worked, show them shift(-1) 
sample_df_releases['double_response'] = np.where(sample_df_releases['shift']==sample_df_releases['Name.2'], 1, 0) # using a numpy where conditional to identify double responses

# Checking that the double response thing worked
double_resp_df = sample_df_releases[sample_df_releases['double_response']==1] 
# display(double_resp_df[['Name.2','shift','double_response']]) # checking that it worked, show them shift(-1)

# Filtering our double response trials
sample_df_releases_nodouble = sample_df_releases[sample_df_releases['double_response']==0] 
print('How many rows in no-double-response filtered data frame:',len(sample_df_releases_nodouble)) # Seeing if we have the right # of rows now
# Out:
# How many rows in initial loaded data frame: 521
# How many rows in key release filtered data frame: 101
# How many rows in no-double-response filtered data frame: 100

# %%
# Demonstrating that Pandas data frames are a collection of series, which are different ways of storing arrays

# display(sample_df_releases) # data frame
display(sample_df_releases['Finger']) # Series w/in the data frame
display(sample_df_releases['Finger'].values) # converting the Data Frame to a numpy array
display(np.array([1, 2, 1, 1, 1, 1, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 1, 1, 1, 2, 1,
       2, 2, 1, 1, 2, 1, 2, 1, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 1, 1, 2, 1,
       1, 1, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 1, 1, 1, 2, 1, 2, 1, 1, 1, 2,
       2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 1, 2, 1, 1, 2, 1, 1, 2, 1, 2, 1,
       2, 1, 2, 1, 2, 2, 1, 2, 1, 1, 1, 2, 2]))
# Out:
# 49     1
# 54     2
# 58     1
# 63     1
# 67     1
#       ..
# 499    1
# 504    1
# 509    1
# 514    2
# 519    2
# Name: Finger, Length: 101, dtype: int64
# array([1, 2, 1, 1, 1, 1, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 1, 1, 1, 2, 1,
#        2, 2, 1, 1, 2, 1, 2, 1, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 1, 1, 2, 1,
#        1, 1, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 1, 1, 1, 2, 1, 2, 1, 1, 1, 2,
#        2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 1, 2, 1, 1, 2, 1, 1, 2, 1, 2, 1,
#        2, 1, 2, 1, 2, 2, 1, 2, 1, 1, 1, 2, 2])
# array([1, 2, 1, 1, 1, 1, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 1, 1, 1, 2, 1,
#        2, 2, 1, 1, 2, 1, 2, 1, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 1, 1, 2, 1,
#        1, 1, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 1, 1, 1, 2, 1, 2, 1, 1, 1, 2,
#        2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 1, 2, 1, 1, 2, 1, 1, 2, 1, 2, 1,
#        2, 1, 2, 1, 2, 2, 1, 2, 1, 1, 1, 2, 2])

# %% [markdown]
# ## 4. Iterate through to load the first level data
# ###    * Concatenate all together to create one data frame to rule them all

# %%
### Part 4 --> Iterating through to get all the first level data, concatenating into allsubs data frame

pid_counter = 1
dfs_list = [] # creating a list of pandas objects

for cur_file in all_files:
    # Copying same logic from our test subject
#     print(cur_file)
    cur_df = pd.read_csv(cur_file, error_bad_lines=False, skiprows=5, sep='\t') 
    cur_df_releases = cur_df[(cur_df['Released']=='Released') & (cur_df['Name.1']=="AI_Block")] 
#     print('How many rows in key release filtered data frame:',cur_df_releases['Congruence'].count()) # What things might cause this to not == 100? For now, just worry baout double responses. For this task, error rates so low that miss response trials not really important.
    cur_df_releases['double_response'] = np.where(cur_df_releases['Name.2'].shift()==cur_df_releases['Name.2'], 1, 0) # faster way to find double responses
    cur_df_releases_nodouble = cur_df_releases[cur_df_releases['double_response']==0] 
#     print('How many rows in no-double-response filtered data frame:',cur_df_releases_nodouble['Congruence'].count()) # Seeing if we have the right # of rows now
    # Appending all the data into a data frame
    dfs_list.append(cur_df_releases_nodouble)
    pid_counter+=1

# Concatenate all DFs together along the row axis
allsubs_df = pd.concat(dfs_list, axis=0)

# Checking what we got and making sure it makes sense given how many trials we should have
# display(dfs_list)
display(allsubs_df)
print('the participant counter from our loop:',pid_counter-1,'should be roughly equivalent to our # of rows / 100:',allsubs_df['Congruence'].count() / 100)
# Out:
#           Group Name    Name.1        Name.2  \
# 49   Main Group   P8  AI_Block   AI_Trial, 7
# 54   Main Group   P8  AI_Block  AI_Trial, 10
# 58   Main Group   P8  AI_Block   AI_Trial, 5
# 63   Main Group   P8  AI_Block   AI_Trial, 9
# 67   Main Group   P8  AI_Block   AI_Trial, 3
# ..          ...  ...       ...           ...
# 467  Main Group  P41  AI_Block   AI_Trial, 4
# 473  Main Group  P41  AI_Block   AI_Trial, 8
# 477  Main Group  P41  AI_Block   AI_Trial, 5
# 481  Main Group  P41  AI_Block   AI_Trial, 6
# 489  Main Group  P41  AI_Block   AI_Trial, 9
#
#                                 Name.3 Response Key  Released  \
# 49              AI_Blue (7, i5inc.bmp)    index   v  Released
# 54            AI_Blue (10, m5base.bmp)   middle   b  Released
# 58       AI_Final_Stage (5, i4con.bmp)    index   v  Released
# 63             AI_Blue (9, i5base.bmp)    index   v  Released
# 67   AI_Final_Stage (3, i4baseinc.bmp)    index   v  Released
# ..                                 ...      ...  ..       ...
# 467  AI_Final_Stage (4, m4baseinc.bmp)    index   v  Released
# 473      AI_Final_Stage (8, m4inc.bmp)   middle   b  Released
# 477      AI_Final_Stage (5, i4con.bmp)    index   v  Released
# 481      AI_Final_Stage (6, m4con.bmp)   middle   b  Released
# 489     AI_Final_Stage (9, i4base.bmp)    index   v  Released
#
#                 Response.1 Code  Time  (Trial Variable)  Finger  Congruence  \
# 49   (based on code value)    C   756               NaN       1           4
# 54   (based on code value)    C   663               NaN       2           0
# 58   (based on code value)    C   532               NaN       1           3
# 63   (based on code value)    C   616               NaN       1           0
# 67   (based on code value)    C   536               NaN       1           2
# ..                     ...  ...   ...               ...     ...         ...
# 467  (based on code value)    E   513               NaN       2           2
# 473  (based on code value)    C   517               NaN       2           4
# 477  (based on code value)    C   355               NaN       1           3
# 481  (based on code value)    C   440               NaN       2           3
# 489  (based on code value)    C   522               NaN       1           0
#
#      Repeated  Correct  double_response
# 49          1      NaN                0
# 54          1      NaN                0
# 58          1      NaN                0
# 63          1      NaN                0
# 67          1      NaN                0
# ..        ...      ...              ...
# 467        10      NaN                0
# 473        10      NaN                0
# 477        10      NaN                0
# 481        10      NaN                0
# 489        10      NaN                0
#
# [4745 rows x 17 columns]
# the participant counter from our loop: 48 should be roughly equivalent to our # of rows / 100: 47.45

# %% [markdown]
# ## 5. Merge with questionnaire data

# %%
### Part 5 --> Loading in the questionnaire data and merging it with behavioral data

# renaming pid column in data frame
# print(allsubs_df['Name'])
allsubs_df = allsubs_df.rename(columns={"Name": "pid"})

# Reading in the npi data data
questionnaire_df = pd.read_csv(questionnaire_file)
display(questionnaire_df)

# Merging the npi and main df
allsubs_df = pd.merge(allsubs_df,questionnaire_df,how='outer',on='pid')
display(allsubs_df)
# Out:
#     pid  questionnaire_1  questionnaire_2  questionnaire_3  questionnaire_4  \
# 0    P8               62               22               74               37
# 1    P9                0               60               95               30
# 2   P49                0               36               88               13
# 3   P48                9               82                6               96
# 4   P13               60               69               15               62
# 5   P12               57               54               25               76
# 6   P38               66                9               63               35
# 7   P10               21               76               76               70
# 8   P11               22               20               92               57
# 9   P39               18               69               40               14
# 10  P15               71               75               19               59
# 11  P29               51               71               46               50
# 12  P28               10                8               13               96
# 13  P14               85               20               35               78
# 14  P16               30               50                5               51
# 15  P17               51               55               95               81
# 16  P32               67               44               44               41
# 17  P26               68               42               35               13
# 18  P27               69               96                9               86
# 19  P33               50               42                8                6
# 20  P19               83               20               65               84
# 21  P25               56               83               79               36
# 22  P31               58               18               88               14
# 23  P30               70               94               84               55
# 24  P24               98               16               88               75
# 25  P18               83                4               85               57
# 26  P20               85               10               70               99
# 27  P34               81               14               20               88
# 28  P35               38               58               49               25
# 29  P21               92               69               90               28
# 30  P37               63               66                7               56
# 31  P23                2                0               30               66
# 32  P22               35               24               47               84
# 33  P36               61                5               10               12
# 34  P45               70               41               41               51
# 35   P2               64               48               47               66
# 36   P3               47               80               27               67
# 37  P44               46               47               18               55
# 38  P46               73               80               92               84
# 39   P1               63               11               45               37
# 40  P47               60               99               50               45
# 41  P43               95               87               13               64
# 42   P5               19               48               82               14
# 43  P42               60               91               70               93
# 44  P40               48               37               20               15
# 45   P7               35               14               12               81
# 46   P6               69                3               59               37
# 47  P41               74               78               11               82
#
#     questionnaire_5  questionnaire_6  questionnaire_7  questionnaire_8  \
# 0                62               32               46               56
# 1                68               29               93               52
# 2                14               20               36                5
# 3                18               66               87               34
# 4                88               29               37               74
# 5                54               50                2               92
# 6                97               42               44               61
# 7                14               81               44               57
# 8                36               34               90               30
# 9                12               88               53               31
# 10               15               36               20                2
# 11               94               71               70               91
# 12               35               18               65               48
# 13               94               25               72               47
# 14               76               78               54               29
# 15               92               89               92               83
# 16               89               99               14               47
# 17               40               34               48               44
# 18                8               28               80               36
# 19               56               64                2               65
# 20               75               73               56               62
# 21               44               44               82               53
# 22               80               78               26                8
# 23               57               12               14               70
# 24               79               27               65               24
# 25               99               59               62               31
# 26               61               31                0               42
# 27               85               12               44               63
# 28               23               77               34               11
# 29               60               62                8               90
# 30               85               22               19               81
# 31               28               28               47               86
# 32               68               46               20               47
# 33               48                3               50               21
# 34               98               54               30               90
# 35               22               39               11               43
# 36               32               39                2               91
# 37                2               64                2               94
# 38               53               32               11               19
# 39               18               42               83               22
# 40               11               60               44               43
# 41               72               82               39               76
# 42               77               67                0               96
# 43                0               60               33               16
# 44               11               35               92               67
# 45               77                7               61               58
# 46               37               91               20               96
# 47               74               54                8               36
#
#     questionnaire_9  questionnaire_10
# 0                43                78
# 1                55                64
# 2                78                12
# 3                22                75
# 4                 7                40
# 5                43                83
# 6                58                34
# 7                31                29
# 8                72                57
# 9                71                26
# 10               24                37
# 11               30                96
# 12               27                 5
# 13                1                19
# 14               50                25
# 15               81                 8
# 16               13                 2
# 17               63                25
# 18               51                32
# 19               74                74
# 20               35                74
# 21               92                37
# 22               43                97
# 23               67                65
# 24               89                22
# 25               25                25
# 26               24                 9
# 27               43                62
# 28               92                84
# 29               42                15
# 30               80                 0
# 31               56                62
# 32               97                25
# 33               29                13
# 34               60                96
# 35               47                23
# 36               17                23
# 37               44                89
# 38               39                 4
# 39               80                14
# 40               93                 5
# 41               75                 7
# 42               90                32
# 43               58                20
# 44               93                20
# 45               71                20
# 46               63                59
# 47               73                22
#            Group  pid    Name.1        Name.2  \
# 0     Main Group   P8  AI_Block   AI_Trial, 7
# 1     Main Group   P8  AI_Block  AI_Trial, 10
# 2     Main Group   P8  AI_Block   AI_Trial, 5
# 3     Main Group   P8  AI_Block   AI_Trial, 9
# 4     Main Group   P8  AI_Block   AI_Trial, 3
# ...          ...  ...       ...           ...
# 4740  Main Group  P41  AI_Block   AI_Trial, 4
# 4741  Main Group  P41  AI_Block   AI_Trial, 8
# 4742  Main Group  P41  AI_Block   AI_Trial, 5
# 4743  Main Group  P41  AI_Block   AI_Trial, 6
# 4744  Main Group  P41  AI_Block   AI_Trial, 9
#
#                                  Name.3 Response Key  Released  \
# 0                AI_Blue (7, i5inc.bmp)    index   v  Released
# 1              AI_Blue (10, m5base.bmp)   middle   b  Released
# 2         AI_Final_Stage (5, i4con.bmp)    index   v  Released
# 3               AI_Blue (9, i5base.bmp)    index   v  Released
# 4     AI_Final_Stage (3, i4baseinc.bmp)    index   v  Released
# ...                                 ...      ...  ..       ...
# 4740  AI_Final_Stage (4, m4baseinc.bmp)    index   v  Released
# 4741      AI_Final_Stage (8, m4inc.bmp)   middle   b  Released
# 4742      AI_Final_Stage (5, i4con.bmp)    index   v  Released
# 4743      AI_Final_Stage (6, m4con.bmp)   middle   b  Released
# 4744     AI_Final_Stage (9, i4base.bmp)    index   v  Released
#
#                  Response.1 Code  ...  questionnaire_1  questionnaire_2  \
# 0     (based on code value)    C  ...               62               22
# 1     (based on code value)    C  ...               62               22
# 2     (based on code value)    C  ...               62               22
# 3     (based on code value)    C  ...               62               22
# 4     (based on code value)    C  ...               62               22
# ...                     ...  ...  ...              ...              ...
# 4740  (based on code value)    E  ...               74               78
# 4741  (based on code value)    C  ...               74               78
# 4742  (based on code value)    C  ...               74               78
# 4743  (based on code value)    C  ...               74               78
# 4744  (based on code value)    C  ...               74               78
#
#       questionnaire_3  questionnaire_4  questionnaire_5  questionnaire_6  \
# 0                  74               37               62               32
# 1                  74               37               62               32
# 2                  74               37               62               32
# 3                  74               37               62               32
# 4                  74               37               62               32
# ...               ...              ...              ...              ...
# 4740               11               82               74               54
# 4741               11               82               74               54
# 4742               11               82               74               54
# 4743               11               82               74               54
# 4744               11               82               74               54
#
#       questionnaire_7  questionnaire_8  questionnaire_9  questionnaire_10
# 0                  46               56               43                78
# 1                  46               56               43                78
# 2                  46               56               43                78
# 3                  46               56               43                78
# 4                  46               56               43                78
# ...               ...              ...              ...               ...
# 4740                8               36               73                22
# 4741                8               36               73                22
# 4742                8               36               73                22
# 4743                8               36               73                22
# 4744                8               36               73                22
#
# [4745 rows x 27 columns]

# %% [markdown]
# ## 6. Write to trial-level allsubjects csv

# %%
### Part 6 --> Write data to a csv

# Writing the data to a second-level data frame that we will eventually play with in R
out_filename = os.path.join(second_dir,'ait_trialwise.csv')
allsubs_df.to_csv(out_filename,index=False)

# %% [markdown]
# #### Pick up next class..
# 7. Compute summary measures
# 8. Save to summary allsubjects csv
